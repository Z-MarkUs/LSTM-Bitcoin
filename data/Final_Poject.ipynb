# %% [markdown]
# # APS1052 Final Project - LSTM Bitcoin

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data
# The data set is already downloaded for us from the Glassnode

# %%
# Load the dataset
file_path = "btc_dataset.csv"  # Replace with your dataset path
df = pd.read_csv(file_path, parse_dates=['Date'], index_col='Date')

# Preview the data
df.head()
# Out:
#             Closing Price (USD)  active_addresses         hash_rate  \
# Date
# 2013-10-01            123.65499             89218  1309351515956620
# 2013-10-02            125.45500            105303  1307159450402430
# 2013-10-03            108.58483             89993  1452700445873280
# 2013-10-04            118.67466             77370  1283409529949880
# 2013-10-05            121.33866             64961  1602048841926960
#
#              btc_left  total_addresses          difficulty  total_fees  \
# Date
# 2013-10-01  9220600.0         18656301  639173596179762000   39.139746
# 2013-10-02  9215825.0         18708039  639173596179762000   39.923033
# 2013-10-03  9210850.0         18751619  639173596179762000   36.602946
# 2013-10-04  9206350.0         18791964  639173596179762000   24.772795
# 2013-10-05  9200875.0         18823649  639173596179762000   26.062425
#
#               fed_assets         GLD        IYE    SLV         SPY  \
# Date
# 2013-10-01  3.747387e+06  124.589996  47.430000  20.41  169.339996
# 2013-10-02  3.747387e+06  127.059998  47.540001  20.92  169.179993
# 2013-10-03  3.748998e+06  127.180000  47.099998  20.92  167.619995
# 2013-10-04  3.750609e+06  126.529999  47.520000  20.93  168.889999
# 2013-10-05  3.752220e+06  126.529999  47.520000  20.93  168.889999
#
#                    TLT        UUP  NYFed_inflation  Google_popularity
# Date
# 2013-10-01  105.800003  21.610001         1.738484                  3
# 2013-10-02  105.959999  21.530001         1.738484                  3
# 2013-10-03  105.790001  21.510000         1.738484                  3
# 2013-10-04  105.709999  21.610001         1.738484                  3
# 2013-10-05  105.709999  21.610001         1.738484                  3

# %% [markdown]
# Check if there is any missing value.

# %%
# Check for missing values in the dataset
missing_values = df.isnull().sum()

# Filter columns with missing values
missing_columns = missing_values[missing_values > 0]

# Display the result
if missing_columns.empty:
    print("No missing values in the dataset.")
else:
    print("Missing values in each column:")
    print(missing_columns)

    # Visualize missing data
    plt.figure(figsize=(12, 6))
    missing_columns.plot(kind='bar', title="Count of Missing Values by Column")
    plt.xlabel("Columns")
    plt.ylabel("Number of Missing Values")
    plt.show()
# Out:
# No missing values in the dataset.

# %% [markdown]
# # Loading Data

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### 1. Realized Volatility (14-day Rolling)
# - **How to Derive**: Compute the rolling standard deviation of the "Closing Price (USD)" log returns over the past 14 days.
# - **Implementation**:
#     $$
#     \text{Realized Volatility} = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (\log(P_t/P_{t-1}))^2}
#     $$
# - **Relevant Columns**: `"Closing Price (USD)"`

# %%
# Calculate log returns
df['log_return'] = np.log(df['Closing Price (USD)'] / df['Closing Price (USD)'].shift(1))

# Calculate realized volatility (14-day rolling standard deviation)
df['realized_volatility'] = df['log_return'].rolling(window=14).std()

# Drop the temporary column
df.drop(columns=['log_return'], inplace=True)

# Visualize the feature
plt.figure(figsize=(10, 6))
df['realized_volatility'].plot(title="Realized Volatility (14-day Rolling)")
plt.show()

# %%
# Calculate log returns
df['log_return'] = np.log(df['Closing Price (USD)'] / df['Closing Price (USD)'].shift(1))

# Calculate realized volatility (14-day rolling standard deviation)
df['realized_volatility'] = df['log_return'].rolling(window=14).std()

# Drop the temporary column
df.drop(columns=['log_return'], inplace=True)

# Visualize the feature
plt.figure(figsize=(10, 6))
df['realized_volatility'].plot(title="Realized Volatility (14-day Rolling)")
plt.show()

# %% [markdown]
# #### 2. Exchange Netflow Proxy
# - **How to Derive**: Use `"active_addresses"` as a proxy for activity. Calculate the daily change in `"active_addresses"` or the ratio of `"active_addresses"` to `"total_addresses"`. This can act as a proxy for inflow/outflow activity.
# - **Implementation**:
# $$
#      \text{Netflow Proxy} = \frac{\text{active\_addresses}}{\text{total\_addresses}}
#      $$
# - **Relevant Columns**: `"active_addresses"`, `"total_addresses"`

# %%
# Ratio of active addresses to total addresses as a proxy for netflow
df['exchange_netflow_proxy'] = df['active_addresses'] / df['total_addresses']

# Visualize the feature
plt.figure(figsize=(10, 6))
df['exchange_netflow_proxy'].plot(title="Exchange Netflow Proxy")
plt.show()

# %% [markdown]
# ### 3. Social Sentiment Proxy (Google Popularity Change)
# - **How to Derive**: Use the percentage change or rolling average of `"Google_popularity"` to capture shifts in public interest over time.
# - **Implementation**:
#      $$
#      \text{Google Sentiment} = \frac{\text{Google\_popularity}_t - \text{Google\_popularity}_{t-1}}{\text{Google\_popularity}_{t-1}}
#      $$
# - **Relevant Columns**: `"Google_popularity"`

# %%
# Percentage change in Google Popularity
df['google_sentiment_proxy'] = df['Google_popularity'].pct_change()

# Visualize the feature
plt.figure(figsize=(10, 6))
df['google_sentiment_proxy'].plot(title="Google Sentiment Proxy")
plt.show()

# %% [markdown]
# ### 4. Funding Rates Proxy (Mining Cost Ratio)
#    - **How to Derive**: Calculate the ratio of `"hash_rate"` to `"difficulty"`, which can act as a proxy for mining costs and potential supply-side pressures.
#    - **Implementation**:
#      $$
#      \text{Mining Cost Ratio} = \frac{\text{hash\_rate}}{\text{difficulty}}
#      $$
#    - **Relevant Columns**: `"hash_rate"`, `"difficulty"`

# %%
# Convert columns to numeric
df['hash_rate'] = pd.to_numeric(df['hash_rate'], errors='coerce')
df['difficulty'] = pd.to_numeric(df['difficulty'], errors='coerce')

# Mining cost ratio as a proxy for funding rates
df['funding_rate_proxy'] = df['hash_rate'] / df['difficulty']

# Visualize the feature
plt.figure(figsize=(10, 6))
df['funding_rate_proxy'].plot(title="Funding Rates Proxy")
plt.show()

# %% [markdown]
# ### 5. Macro Interaction Proxy (GLD-SPY Interaction)
#    - **How to Derive**: Create interaction terms between `"GLD"` (gold prices) and `"SPY"` (S&P 500 index) to capture broader macroeconomic influences. This could be the product or difference between the two.
#    - **Implementation**:
#      $$
#      \text{GLD-SPY Interaction} = \text{GLD} \times \text{SPY}
#      $$
#    - **Relevant Columns**: `"GLD"`, `"SPY"`

# %% [markdown]
# Check if there is any missing value.

# %%
# Interaction between GLD and SPY
df['macro_interaction_proxy'] = df['GLD'] * df['SPY']

# Visualize the feature
plt.figure(figsize=(10, 6))
df['macro_interaction_proxy'].plot(title="Macro Interaction Proxy (GLD * SPY)")
plt.show()

# %%
# Check for missing values in the dataset
missing_values = df.isnull().sum()

# Filter columns with missing values
missing_columns = missing_values[missing_values > 0]

# Display the result
if missing_columns.empty:
    print("No missing values in the dataset.")
else:
    print("Missing values in each column:")
    print(missing_columns)

    # Visualize missing data
    plt.figure(figsize=(12, 6))
    missing_columns.plot(kind='bar', title="Count of Missing Values by Column")
    plt.xlabel("Columns")
    plt.ylabel("Number of Missing Values")
    plt.show()
# Out:
# Missing values in each column:
# realized_volatility       14
# google_sentiment_proxy     1
# dtype: int64

# %% [markdown]
# This caused by the way we calculate the two features.
# We have two different options:
# 1. `NaN`
# 2. `0`
#
# Which Option to Choose?
# - **For Long-Term Models or Sparse Data:** Use **Option 1** (`NaN`) and drop rows with missing values. This maintains the integrity of the calculations.
# - **For Time Series Models with Long Sequences:** Use **Option 2** (fill with `0`) to avoid breaking sequence continuity.
#
# Since we are working with LSTMs and sequences, Option 2 (setting to `0`) is more practical:
# - It avoids disrupting sequences, which is critical for time series models.
# - The missing data period (**14** days for volatility, **1** day for sentiment) is short, so the impact of filling with `0` is minimal.

# %%
df['realized_volatility'] = df['realized_volatility'].fillna(0)
df['google_sentiment_proxy'] = df['google_sentiment_proxy'].fillna(0)

# %% [markdown]
# ### Feature Drop
# Features with sparse and infrequent activity may not significantly contribute to the model's predictions. As most values in `df['google_sentiment_proxy']` is zero, we decided to drop it.

# %%
# Drop the Google Sentiment Proxy column from the dataset
df.drop(columns=['google_sentiment_proxy'], inplace=True)

# %%
# # Save the current DataFrame to a CSV file
# file_path = "data/BTC_data.csv"
# df.to_csv(file_path, index=True)

# %% [markdown]
# ## Dataset Preparation

# %% [markdown]
# ### Dataset Split

# %%
# Define split ratios
train_ratio = 0.64  # 64% for training (80% of Train + Validation)
validation_ratio = 0.16  # 16% for validation (20% of Train + Validation)
test_ratio = 0.20  # 20% for testing

# Calculate indices for splits
train_end_index = int(len(df) * train_ratio)
validation_end_index = int(len(df) * (train_ratio + validation_ratio))

# Sequential split
train_data = df.iloc[:train_end_index]
validation_data = df.iloc[train_end_index:validation_end_index]
test_data = df.iloc[validation_end_index:]

# Print the shapes
print(f"Training data shape: {train_data.shape}")
print(f"Validation data shape: {validation_data.shape}")
print(f"Testing data shape: {test_data.shape}")
# Out:
# Training data shape: (1635, 20)
# Validation data shape: (409, 20)
# Testing data shape: (512, 20)

# %% [markdown]
# ### Data Normalization

# %% [markdown]
# **Why Normalize Data for Bitcoin Price Prediction?**
# Normalization is a crucial preprocessing step for time series forecasting tasks, especially for Bitcoin price prediction, because:
#
# 1. **Stabilizing the Scale**:
#    - Bitcoin price and other features (e.g., hash rate, difficulty, or macroeconomic factors) can have vastly different scales.
#    - Normalizing the data ensures all features are on a similar scale, making it easier for the LSTM to learn patterns.
#
# 2. **Improving Model Training**:
#    - Models like LSTMs are sensitive to the magnitude of input values. If the input features are not normalized, the gradient updates during training can become unstable.
#    - Normalized data ensures smoother gradients and faster convergence.
#
# 3. **Relative Changes Over Absolute Values**:
#    - For financial data like Bitcoin prices, the relative change in values (e.g., percent change) is often more important than absolute values.
#    - By normalizing sequences relative to their starting value (e.g., the first value in each sequence), we emphasize the relative dynamics within the window.
#
# 4. **Simplifying Interpretation**:
#    - Normalizing data to start at a baseline of 0 makes it easier to interpret the model's output relative to the starting point of the sequence.
#
# **Formula for Normalization:**
# The data is normalized using the first value in each sequence as the baseline:
# $$
# \text{Normalized Value} = \left(\frac{\text{Value}}{\text{First Value}} \right) - 1
# $$
# This ensures each sequence starts at a normalized value of 0.
#
# ---
#
# **Why Use a Window for BTC Forecasting?**
# The **lookback window** defines how many past days' data the model considers when making predictions. This choice is important for time series forecasting because:
#
# 1. **Capturing Temporal Patterns**:
#    - Bitcoin prices and on-chain metrics (e.g., hash rate, active addresses) exhibit temporal dependencies. Using a window allows the model to identify these patterns, such as trends and cycles.
#
# 2. **Avoiding Overfitting**:
#    - A window that’s too large includes excessive noise and irrelevant data, leading to overfitting.
#    - A smaller window focuses on more recent, relevant data, improving model generalization.
#
# 3. **Balancing Short-Term and Long-Term Trends**:
#    - Bitcoin prices are influenced by both short-term (e.g., market sentiment) and long-term trends (e.g., macroeconomic conditions). The window length determines the balance between these two.
#
# 4. **Practicality for Financial Decisions**:
#    - In practical trading scenarios, decisions often rely on recent data rather than a full historical analysis. A well-chosen window ensures the model’s output aligns with real-world decision-making.
#
# **Typical Window Setting for BTC:**
# - For daily data, a **21-day window** (3 weeks) is used to predict 3 days ahead:
#   - Captures short-term trends effectively.
#   - Includes enough data to detect meaningful patterns without introducing excessive noise.

# %%
# Define the lookback window
lookback_window = 21  # Use the past 21 days to predict the target,
steps_ahead = 3  # Predict 3 days ahead
window = lookback_window + steps_ahead # in total 24 days as a window

# Columns with leading zeros
leading_zeros = ['realized_volatility']

# %%
# Function to normalize sequences for training (with leading zero handling)
def normalize_sequences_train(data, columns_with_leading_zeros):
    normalized_data = []
    for i in range(len(data) - window + 1):
        sequence = data.iloc[i:i + window].copy()  # Copy the sequence
        base = sequence.iloc[0].copy()  # Explicitly copy the first row as baseline

        # For problematic columns, find the first non-zero value
        for col in columns_with_leading_zeros:
            non_zero_index = sequence[col].ne(0).idxmax()  # Find the index of the first non-zero value
            if pd.notnull(non_zero_index):  # Ensure the index exists
                base[col] = sequence.loc[non_zero_index, col]  # Set the first non-zero value as the baseline

        # Normalize the sequence
        normalized_sequence = (sequence / base) - 1
        normalized_data.append(normalized_sequence.values)

    return np.array(normalized_data)

# Function to normalize sequences for validation and test (no leading zero handling needed)
def normalize_sequences(data):
    normalized_data = []
    for i in range(len(data) - window + 1):
        sequence = data.iloc[i:i + window].copy()
        base = sequence.iloc[0].copy()
        normalized_sequence = (sequence / base) - 1
        normalized_data.append(normalized_sequence.values)

    return np.array(normalized_data)

# Normalize training data with leading zero handling
train_normalized = normalize_sequences_train(train_data, leading_zeros)

# Normalize validation and test data without leading zero handling
validation_normalized = normalize_sequences(validation_data)
test_normalized = normalize_sequences(test_data)

# Print the shapes of normalized data
print(f"Normalized training data shape: {train_normalized.shape}")
print(f"Normalized validation data shape: {validation_normalized.shape}")
print(f"Normalized testing data shape: {test_normalized.shape}")
# Out:
# Normalized training data shape: (1612, 24, 20)
# Normalized validation data shape: (386, 24, 20)
# Normalized testing data shape: (489, 24, 20)

# %% [markdown]
# Check any `NaN`, `inf` or Anomalous Values in the normalized dataset

# %%
# Function to validate normalized data
def validate_normalized_data(normalized_data):
    # Check for NaN values
    nan_count = np.isnan(normalized_data).sum()
    if nan_count > 0:
        print(f"Warning: Found {nan_count} NaN values in the normalized data.")
        normalized_data[np.isnan(normalized_data)] = 0  # Replace NaN with 0

    # Check for Inf values
    inf_count = np.isinf(normalized_data).sum()
    if inf_count > 0:
        print(f"Warning: Found {inf_count} Inf values in the normalized data.")
        normalized_data[np.isinf(normalized_data)] = 0  # Replace Inf with 0

    # Check for negative or unexpected values (optional, based on your use case)
    if (normalized_data < -1).sum() > 0:
        print("Warning: Found values less than -1. Review the normalization process.")

    print("Validation complete. Normalized data is clean.")
    return normalized_data

# %%
# Validate the normalized datasets
x_train_normalized = validate_normalized_data(train_normalized)
x_validation_normalized = validate_normalized_data(validation_normalized)
x_test_normalized = validate_normalized_data(test_normalized)
# Out:
# Validation complete. Normalized data is clean.
# Validation complete. Normalized data is clean.
# Validation complete. Normalized data is clean.

# %% [markdown]
# ### Y-Values Derivation
#
# We predict 3 days ahead (Multi-Step Predictions), the target value (`y`) corresponds to the `Closing Price (USD)` **3 days after the end of the lookback window**.

# %%
target_column = 'Closing Price (USD)'  # The target column

# %% [markdown]
# #### Normalized

# %%
# Split the normalized data into input (X) and target (y)
def split_x_y(normalized_data, lookback_window, steps_ahead):
    """
    Split normalized data into input (X) and target (y).

    Args:
        normalized_data (np.ndarray): Normalized data with shape (num_windows, window, num_features).
        lookback_window (int): Number of timesteps in the input sequence.
        steps_ahead (int): Number of timesteps in the target sequence.

    Returns:
        tuple: X (inputs) and y (targets).
    """
    # Split the first lookback_window timesteps as X
    X = normalized_data[:, :lookback_window, :]  # Shape: (num_windows, lookback_window, num_features)
    # Split the last steps_ahead timesteps as y
    y = normalized_data[:, lookback_window:, :]  # Shape: (num_windows, steps_ahead, num_features)
    return X, y

# Split the normalized data
X_train_normalized, y_train_normalized = split_x_y(x_train_normalized, lookback_window, steps_ahead)
X_validation_normalized, y_validation_normalized = split_x_y(x_validation_normalized, lookback_window, steps_ahead)
X_test_normalized, y_test_normalized = split_x_y(x_test_normalized, lookback_window, steps_ahead)

# Print the resulting shapes
print(f"Training data shapes: X={X_train_normalized.shape}, y={y_train_normalized.shape}")
print(f"Validation data shapes: X={X_validation_normalized.shape}, y={y_validation_normalized.shape}")
print(f"Testing data shapes: X={X_test_normalized.shape}, y={y_test_normalized.shape}")
# Out:
# Training data shapes: X=(1612, 21, 20), y=(1612, 3, 20)
# Validation data shapes: X=(386, 21, 20), y=(386, 3, 20)
# Testing data shapes: X=(489, 21, 20), y=(489, 3, 20)

# %% [markdown]
# #### Unnormalized

# %%
def create_unnormalized_datasets(data, lookback_window, steps_ahead):
    """
    Create input (X) and target (y) datasets without normalization.

    Args:
        data (pd.DataFrame): Raw input data.
        lookback_window (int): Number of timesteps in the input sequence.
        steps_ahead (int): Number of timesteps in the target sequence.

    Returns:
        tuple: X (inputs) and y (targets).
    """
    window = lookback_window + steps_ahead  # Total window size
    X, Y = [], []
    for i in range(len(data) - window + 1):
        # Input: first `lookback_window` timesteps
        X.append(data.iloc[i:i + lookback_window].values)
        # Target: last `steps_ahead` timesteps
        Y.append(data.iloc[i + lookback_window:i + window].values)
    return np.array(X), np.array(Y)


# Create unnormalized datasets
X_train_un, y_train_un = create_unnormalized_datasets(train_data, lookback_window, steps_ahead)
X_validation_un, y_validation_un = create_unnormalized_datasets(validation_data, lookback_window, steps_ahead)
X_test_un, y_test_un = create_unnormalized_datasets(test_data, lookback_window, steps_ahead)

# Print shapes
print(f"Unnormalized Training data shapes: X={X_train_un.shape}, y={y_train_un.shape}")
print(f"Unnormalized Validation data shapes: X={X_validation_un.shape}, y={y_validation_un.shape}")
print(f"Unnormalized Testing data shapes: X={X_test_un.shape}, y={y_test_un.shape}")
# Out:
# Unnormalized Training data shapes: X=(1612, 21, 20), y=(1612, 3, 20)
# Unnormalized Validation data shapes: X=(386, 21, 20), y=(386, 3, 20)
# Unnormalized Testing data shapes: X=(489, 21, 20), y=(489, 3, 20)

# %% [markdown]
# # LSTM Model

# %% [markdown]
# ## Model Implementation

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Input, Concatenate
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.models import Model

# %% [markdown]
# We use the **Sequence-to-Sequence** (**Seq2Seq**) framework other than a traditional LSTM, as it usually outperforms for multistep forecasting.

# %%
def build_seq2seq_model(input_shape, steps_ahead):
    """
    Build a Sequence-to-Sequence model for multistep forecasting.

    Args:
        input_shape (tuple): Shape of the input sequence (timesteps, features).
        steps_ahead (int): Number of steps ahead to predict.

    Returns:
        model: Compiled Seq2Seq model.
    """
    # Encoder
    encoder_inputs = Input(shape=input_shape, name="encoder_inputs")
    encoder_lstm = LSTM(256, return_state=True, name="encoder_lstm")
    encoder_outputs, state_h, state_c = encoder_lstm(encoder_inputs)

    # Decoder
    decoder_inputs = Input(shape=(1, 1), name="decoder_inputs")  # One timestep, one feature
    decoder_lstm = LSTM(256, return_sequences=True, return_state=True, name="decoder_lstm")
    decoder_dense = Dense(1, activation="linear", name="decoder_dense")  # Predict one output per step

    # Sequentially predict steps_ahead timesteps
    all_outputs = []
    inputs = decoder_inputs
    states = [state_h, state_c]
    for step in range(steps_ahead):
        outputs, state_h, state_c = decoder_lstm(inputs, initial_state=states)
        outputs = decoder_dense(outputs)  # Predict the next value
        all_outputs.append(outputs)
        inputs = outputs  # Use the predicted output as the next input
        states = [state_h, state_c]  # Update the decoder states

    # Concatenate all predictions into the final output sequence
    decoder_outputs = Concatenate(axis=1, name="decoder_outputs")(all_outputs)

    # Define the model
    model = Model([encoder_inputs, decoder_inputs], decoder_outputs, name="seq2seq_model")
    model.compile(optimizer="adam", loss="mse", metrics=["mae"])  # Compile the model
    return model

# Define input shapes
input_shape = (X_train_normalized.shape[1], X_train_normalized.shape[2])  # (lookback_window, num_features)

# Build the model
seq2seq_model = build_seq2seq_model(input_shape, steps_ahead)
seq2seq_model.summary()
# Out:
# Model: "seq2seq_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_inputs      │ (None, 21, 20)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_inputs      │ (None, 1, 1)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_lstm (LSTM) │ [(None, 256),     │    283,648 │ encoder_inputs[0… │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_lstm (LSTM) │ [(None, 1, 256),  │    264,192 │ decoder_inputs[0… │
# │                     │ (None, 256),      │            │ encoder_lstm[0][… │
# │                     │ (None, 256)]      │            │ encoder_lstm[0][… │
# │                     │                   │            │ decoder_dense[0]… │
# │                     │                   │            │ decoder_lstm[0][… │
# │                     │                   │            │ decoder_lstm[0][… │
# │                     │                   │            │ decoder_dense[1]… │
# │                     │                   │            │ decoder_lstm[1][… │
# │                     │                   │            │ decoder_lstm[1][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_dense       │ (None, 1, 1)      │        257 │ decoder_lstm[0][… │
# │ (Dense)             │                   │            │ decoder_lstm[1][… │
# │                     │                   │            │ decoder_lstm[2][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_outputs     │ (None, 3, 1)      │          0 │ decoder_dense[0]… │
# │ (Concatenate)       │                   │            │ decoder_dense[1]… │
# │                     │                   │            │ decoder_dense[2]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 548,097 (2.09 MB)
#  Trainable params: 548,097 (2.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Normalized

# %%
# Extract the target feature (e.g., "Closing Price (USD)") for decoder outputs
target_index = 0  # Assuming the target feature is the first feature in y
y_train_normalized_target = y_train_normalized[:, :, [target_index]]
y_validation_normalized_target = y_validation_normalized[:, :, [target_index]]
y_test_normalized_target = y_test_normalized[:, :, [target_index]]

# Use the first timestep of `y` as the decoder input during training
decoder_input_train = y_train_normalized_target[:, :1, :]  # Shape: (num_samples, 1, 1)
decoder_input_validation = y_validation_normalized_target[:, :1, :]  # Shape: (num_samples, 1, 1)

# %%
# Directory to save the model
normalized_model_save_path = "best_seq2seq_model.keras"

# Callbacks
callbacks = [
    ModelCheckpoint(
        filepath=normalized_model_save_path,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.1,
        patience=3,
        verbose=1
    ),
    EarlyStopping(
        monitor="val_loss",
        patience=5,
        verbose=1,
        restore_best_weights=True
    )
]

# Train the model with callbacks
history = seq2seq_model.fit(
    [X_train_normalized, decoder_input_train],
    y_train_normalized_target,
    validation_data=([X_validation_normalized, decoder_input_validation], y_validation_normalized_target),
    epochs=50,  # Number of epochs
    batch_size=32,  # Mini-batch size
    verbose=1,
    callbacks=callbacks
)

# Find the best epoch based on the lowest validation loss
best_epoch_normalized = np.argmin(history.history['val_loss'])
print(f"The best model was saved at epoch: {best_epoch_normalized + 1}")
# Out:
# Epoch 1/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0778 - mae: 0.1463
# Epoch 1: val_loss improved from inf to 0.00552, saving model to best_seq2seq_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - loss: 0.0752 - mae: 0.1436 - val_loss: 0.0055 - val_mae: 0.0543 - learning_rate: 0.0010
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0097 - mae: 0.0595
# Epoch 2: val_loss did not improve from 0.00552
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0097 - mae: 0.0595 - val_loss: 0.0080 - val_mae: 0.0626 - learning_rate: 0.0010
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0116 - mae: 0.0662
# Epoch 3: val_loss did not improve from 0.00552
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0116 - mae: 0.0662 - val_loss: 0.0059 - val_mae: 0.0518 - learning_rate: 0.0010
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0080 - mae: 0.0569
# Epoch 4: val_loss did not improve from 0.00552
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0080 - mae: 0.0570 - val_loss: 0.0118 - val_mae: 0.0674 - learning_rate: 0.0010
# Epoch 5/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0088 - mae: 0.0602
# Epoch 5: val_loss improved from 0.00552 to 0.00352, saving model to best_seq2seq_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0088 - mae: 0.0599 - val_loss: 0.0035 - val_mae: 0.0422 - learning_rate: 1.0000e-04
# Epoch 6/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0073 - mae: 0.0480
# Epoch 6: val_loss improved from 0.00352 to 0.00346, saving model to best_seq2seq_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0072 - mae: 0.0479 - val_loss: 0.0035 - val_mae: 0.0412 - learning_rate: 1.0000e-04
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0067 - mae: 0.0468
# Epoch 7: val_loss did not improve from 0.00346
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0067 - mae: 0.0468 - val_loss: 0.0035 - val_mae: 0.0415 - learning_rate: 1.0000e-04
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0067 - mae: 0.0462
# Epoch 8: val_loss improved from 0.00346 to 0.00339, saving model to best_seq2seq_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0066 - mae: 0.0462 - val_loss: 0.0034 - val_mae: 0.0409 - learning_rate: 1.0000e-04
# Epoch 9/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0059 - mae: 0.0465
# Epoch 9: val_loss did not improve from 0.00339
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0059 - mae: 0.0464 - val_loss: 0.0035 - val_mae: 0.0411 - learning_rate: 1.0000e-04
# Epoch 10/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0064 - mae: 0.0473
# Epoch 10: val_loss improved from 0.00339 to 0.00338, saving model to best_seq2seq_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0064 - mae: 0.0473 - val_loss: 0.0034 - val_mae: 0.0405 - learning_rate: 1.0000e-04
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0047 - mae: 0.0432
# Epoch 11: val_loss improved from 0.00338 to 0.00334, saving model to best_seq2seq_model.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0048 - mae: 0.0432 - val_loss: 0.0033 - val_mae: 0.0403 - learning_rate: 1.0000e-04
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0053 - mae: 0.0431
# Epoch 12: val_loss did not improve from 0.00334
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0053 - mae: 0.0431 - val_loss: 0.0034 - val_mae: 0.0404 - learning_rate: 1.0000e-05
# Epoch 13/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0058 - mae: 0.0468
# Epoch 13: val_loss did not improve from 0.00334
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0058 - mae: 0.0467 - val_loss: 0.0034 - val_mae: 0.0406 - learning_rate: 1.0000e-05
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0057 - mae: 0.0448
# Epoch 14: val_loss did not improve from 0.00334
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0057 - mae: 0.0448 - val_loss: 0.0034 - val_mae: 0.0405 - learning_rate: 1.0000e-05
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0054 - mae: 0.0448
# Epoch 15: val_loss did not improve from 0.00334
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0054 - mae: 0.0448 - val_loss: 0.0034 - val_mae: 0.0406 - learning_rate: 1.0000e-06
# Epoch 16/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0049 - mae: 0.0423
# Epoch 16: val_loss did not improve from 0.00334
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0049 - mae: 0.0424 - val_loss: 0.0034 - val_mae: 0.0406 - learning_rate: 1.0000e-06
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 11.
# The best model was saved at epoch: 11

# %% [markdown]
# ### Unnormalized

# %%
# Extract the target feature (e.g., "Closing Price (USD)") for decoder outputs
target_index = 0  # Assuming the target feature is the first feature in y
y_train_un_target = y_train_un[:, :, [target_index]]
y_validation_un_target = y_validation_un[:, :, [target_index]]
y_test_un_target = y_test_un[:, :, [target_index]]

# Use the first timestep of `y` as the decoder input during training
decoder_input_train_un = y_train_un_target[:, :1, :]  # Shape: (num_samples, 1, 1)
decoder_input_validation_un = y_validation_un_target[:, :1, :]  # Shape: (num_samples, 1, 1)

# Build the model
seq2seq_model_un = build_seq2seq_model(input_shape=(X_train_un.shape[1], X_train_un.shape[2]), steps_ahead=steps_ahead)
seq2seq_model_un.summary()
# Out:
# Model: "seq2seq_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_inputs      │ (None, 21, 20)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_inputs      │ (None, 1, 1)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_lstm (LSTM) │ [(None, 256),     │    283,648 │ encoder_inputs[0… │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_lstm (LSTM) │ [(None, 1, 256),  │    264,192 │ decoder_inputs[0… │
# │                     │ (None, 256),      │            │ encoder_lstm[0][… │
# │                     │ (None, 256)]      │            │ encoder_lstm[0][… │
# │                     │                   │            │ decoder_dense[0]… │
# │                     │                   │            │ decoder_lstm[0][… │
# │                     │                   │            │ decoder_lstm[0][… │
# │                     │                   │            │ decoder_dense[1]… │
# │                     │                   │            │ decoder_lstm[1][… │
# │                     │                   │            │ decoder_lstm[1][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_dense       │ (None, 1, 1)      │        257 │ decoder_lstm[0][… │
# │ (Dense)             │                   │            │ decoder_lstm[1][… │
# │                     │                   │            │ decoder_lstm[2][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_outputs     │ (None, 3, 1)      │          0 │ decoder_dense[0]… │
# │ (Concatenate)       │                   │            │ decoder_dense[1]… │
# │                     │                   │            │ decoder_dense[2]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 548,097 (2.09 MB)
#  Trainable params: 548,097 (2.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define callbacks
unnormalized_model_save_path = "best_seq2seq_model_unnormalized.keras"
callbacks_un = [
    ModelCheckpoint(
        filepath=unnormalized_model_save_path,
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.1,
        patience=3,
        verbose=1
    ),
    EarlyStopping(
        monitor="val_loss",
        patience=5,
        verbose=1,
        restore_best_weights=True
    )
]

# Train the Seq2Seq model
history_un = seq2seq_model_un.fit(
    [X_train_un, decoder_input_train_un],
    y_train_un_target,
    validation_data=([X_validation_un, decoder_input_validation_un], y_validation_un_target),
    epochs=50,  # Number of epochs
    batch_size=32,  # Mini-batch size
    verbose=1,
    callbacks=callbacks_un
)

# Find the best epoch based on the lowest validation loss
best_epoch_un = np.argmin(history_un.history['val_loss'])
print(f"The best model was saved at epoch: {best_epoch_un + 1}")
# Out:
# Epoch 1/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 14210317.0000 - mae: 1900.5070
# Epoch 1: val_loss improved from inf to 35875592.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 14173134.0000 - mae: 1895.0475 - val_loss: 35875592.0000 - val_mae: 5741.8613 - learning_rate: 0.0010
# Epoch 2/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 14558712.0000 - mae: 1868.8396
# Epoch 2: val_loss improved from 35875592.00000 to 35708892.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 14479054.0000 - mae: 1861.5466 - val_loss: 35708892.0000 - val_mae: 5727.3281 - learning_rate: 0.0010
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 13234726.0000 - mae: 1755.6504
# Epoch 3: val_loss improved from 35708892.00000 to 35556032.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 13232803.0000 - mae: 1755.1167 - val_loss: 35556032.0000 - val_mae: 5713.9668 - learning_rate: 0.0010
# Epoch 4/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 12077322.0000 - mae: 1633.3140
# Epoch 4: val_loss improved from 35556032.00000 to 35419460.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 12116293.0000 - mae: 1636.4731 - val_loss: 35419460.0000 - val_mae: 5702.0034 - learning_rate: 0.0010
# Epoch 5/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 14963468.0000 - mae: 1842.1908
# Epoch 5: val_loss improved from 35419460.00000 to 35284556.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 14889888.0000 - mae: 1836.8486 - val_loss: 35284556.0000 - val_mae: 5690.1592 - learning_rate: 0.0010
# Epoch 6/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 13381247.0000 - mae: 1705.5155
# Epoch 6: val_loss improved from 35284556.00000 to 35152448.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 13360999.0000 - mae: 1704.7402 - val_loss: 35152448.0000 - val_mae: 5678.5371 - learning_rate: 0.0010
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 13007958.0000 - mae: 1676.7678
# Epoch 7: val_loss improved from 35152448.00000 to 35021796.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 13007267.0000 - mae: 1676.8352 - val_loss: 35021796.0000 - val_mae: 5667.0186 - learning_rate: 0.0010
# Epoch 8/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12108394.0000 - mae: 1601.3159
# Epoch 8: val_loss improved from 35021796.00000 to 34896704.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 12140140.0000 - mae: 1603.9185 - val_loss: 34896704.0000 - val_mae: 5655.9702 - learning_rate: 0.0010
# Epoch 9/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 14220617.0000 - mae: 1745.0714
# Epoch 9: val_loss improved from 34896704.00000 to 34766372.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 14144289.0000 - mae: 1740.0082 - val_loss: 34766372.0000 - val_mae: 5644.4341 - learning_rate: 0.0010
# Epoch 10/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 13772760.0000 - mae: 1735.7347
# Epoch 10: val_loss improved from 34766372.00000 to 34637920.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 13737615.0000 - mae: 1732.2902 - val_loss: 34637920.0000 - val_mae: 5633.0420 - learning_rate: 0.0010
# Epoch 11/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12318354.0000 - mae: 1592.0546
# Epoch 11: val_loss improved from 34637920.00000 to 34512224.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 12349115.0000 - mae: 1594.6787 - val_loss: 34512224.0000 - val_mae: 5621.8730 - learning_rate: 0.0010
# Epoch 12/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 12662236.0000 - mae: 1638.6838
# Epoch 12: val_loss improved from 34512224.00000 to 34387960.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 12666966.0000 - mae: 1638.1064 - val_loss: 34387960.0000 - val_mae: 5610.8076 - learning_rate: 0.0010
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12694813.0000 - mae: 1578.2020
# Epoch 13: val_loss improved from 34387960.00000 to 34260264.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 12695858.0000 - mae: 1578.8629 - val_loss: 34260264.0000 - val_mae: 5599.4141 - learning_rate: 0.0010
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 14784096.0000 - mae: 1716.8428
# Epoch 14: val_loss improved from 34260264.00000 to 34137148.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 14744275.0000 - mae: 1714.6201 - val_loss: 34137148.0000 - val_mae: 5588.4072 - learning_rate: 0.0010
# Epoch 15/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 13620936.0000 - mae: 1656.0173
# Epoch 15: val_loss improved from 34137148.00000 to 34010724.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 13584644.0000 - mae: 1653.4766 - val_loss: 34010724.0000 - val_mae: 5577.0820 - learning_rate: 0.0010
# Epoch 16/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 12617576.0000 - mae: 1608.1737
# Epoch 16: val_loss improved from 34010724.00000 to 33893736.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 12620242.0000 - mae: 1606.5356 - val_loss: 33893736.0000 - val_mae: 5566.5815 - learning_rate: 0.0010
# Epoch 17/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 12484202.0000 - mae: 1519.8049
# Epoch 17: val_loss improved from 33893736.00000 to 33775724.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 12489021.0000 - mae: 1521.6970 - val_loss: 33775724.0000 - val_mae: 5555.9678 - learning_rate: 0.0010
# Epoch 18/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12678869.0000 - mae: 1561.3597
# Epoch 18: val_loss improved from 33775724.00000 to 33656136.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 12674923.0000 - mae: 1561.2533 - val_loss: 33656136.0000 - val_mae: 5545.1904 - learning_rate: 0.0010
# Epoch 19/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 12703339.0000 - mae: 1570.0885
# Epoch 19: val_loss improved from 33656136.00000 to 33537870.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 12697189.0000 - mae: 1569.2723 - val_loss: 33537870.0000 - val_mae: 5534.5142 - learning_rate: 0.0010
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 13354969.0000 - mae: 1582.2659
# Epoch 20: val_loss improved from 33537870.00000 to 33424186.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 13338735.0000 - mae: 1581.4515 - val_loss: 33424186.0000 - val_mae: 5524.2300 - learning_rate: 0.0010
# Epoch 21/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 12309736.0000 - mae: 1533.2903
# Epoch 21: val_loss improved from 33424186.00000 to 33307020.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 12320377.0000 - mae: 1533.2568 - val_loss: 33307020.0000 - val_mae: 5513.6113 - learning_rate: 0.0010
# Epoch 22/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 13418061.0000 - mae: 1618.1702
# Epoch 22: val_loss improved from 33307020.00000 to 33193610.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 13361644.0000 - mae: 1612.6567 - val_loss: 33193610.0000 - val_mae: 5503.3120 - learning_rate: 0.0010
# Epoch 23/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 11889843.0000 - mae: 1499.4926
# Epoch 23: val_loss improved from 33193610.00000 to 33079248.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 11919491.0000 - mae: 1500.3953 - val_loss: 33079248.0000 - val_mae: 5492.9082 - learning_rate: 0.0010
# Epoch 24/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 12378748.0000 - mae: 1476.3634
# Epoch 24: val_loss improved from 33079248.00000 to 32966346.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 12379903.0000 - mae: 1478.2067 - val_loss: 32966346.0000 - val_mae: 5482.6172 - learning_rate: 0.0010
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11332965.0000 - mae: 1445.2128
# Epoch 25: val_loss improved from 32966346.00000 to 32855624.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 11352600.0000 - mae: 1446.2637 - val_loss: 32855624.0000 - val_mae: 5472.5054 - learning_rate: 0.0010
# Epoch 26/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 11502148.0000 - mae: 1420.2229
# Epoch 26: val_loss improved from 32855624.00000 to 32742288.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 11546407.0000 - mae: 1424.2269 - val_loss: 32742288.0000 - val_mae: 5462.1353 - learning_rate: 0.0010
# Epoch 27/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11699709.0000 - mae: 1446.0574
# Epoch 27: val_loss improved from 32742288.00000 to 32629332.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 11722529.0000 - mae: 1447.5696 - val_loss: 32629332.0000 - val_mae: 5451.7812 - learning_rate: 0.0010
# Epoch 28/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11491361.0000 - mae: 1432.8582
# Epoch 28: val_loss improved from 32629332.00000 to 32517134.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 11537423.0000 - mae: 1435.5916 - val_loss: 32517134.0000 - val_mae: 5441.4756 - learning_rate: 0.0010
# Epoch 29/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11569204.0000 - mae: 1428.0198
# Epoch 29: val_loss improved from 32517134.00000 to 32407766.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 11581975.0000 - mae: 1428.8691 - val_loss: 32407766.0000 - val_mae: 5431.4116 - learning_rate: 0.0010
# Epoch 30/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 12830048.0000 - mae: 1542.1472
# Epoch 30: val_loss improved from 32407766.00000 to 32295096.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 12794235.0000 - mae: 1537.7905 - val_loss: 32295096.0000 - val_mae: 5421.0239 - learning_rate: 0.0010
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11991546.0000 - mae: 1466.2694
# Epoch 31: val_loss improved from 32295096.00000 to 32187426.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 11995070.0000 - mae: 1466.1467 - val_loss: 32187426.0000 - val_mae: 5411.0786 - learning_rate: 0.0010
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 12607367.0000 - mae: 1534.9117
# Epoch 32: val_loss improved from 32187426.00000 to 32079256.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 12598502.0000 - mae: 1533.3623 - val_loss: 32079256.0000 - val_mae: 5401.0688 - learning_rate: 0.0010
# Epoch 33/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 11915376.0000 - mae: 1389.7264
# Epoch 33: val_loss improved from 32079256.00000 to 31970660.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 11923162.0000 - mae: 1391.9971 - val_loss: 31970660.0000 - val_mae: 5391.0000 - learning_rate: 0.0010
# Epoch 34/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11719350.0000 - mae: 1428.6034
# Epoch 34: val_loss improved from 31970660.00000 to 31878306.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 11742142.0000 - mae: 1429.5228 - val_loss: 31878306.0000 - val_mae: 5382.4092 - learning_rate: 0.0010
# Epoch 35/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 11089405.0000 - mae: 1370.4163
# Epoch 35: val_loss improved from 31878306.00000 to 31755108.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 11126790.0000 - mae: 1372.9871 - val_loss: 31755108.0000 - val_mae: 5370.9585 - learning_rate: 0.0010
# Epoch 36/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 11638030.0000 - mae: 1417.3401
# Epoch 36: val_loss improved from 31755108.00000 to 31650718.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 11653233.0000 - mae: 1417.8628 - val_loss: 31650718.0000 - val_mae: 5361.2251 - learning_rate: 0.0010
# Epoch 37/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12761267.0000 - mae: 1486.4315
# Epoch 37: val_loss improved from 31650718.00000 to 31543372.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 12717067.0000 - mae: 1482.7721 - val_loss: 31543372.0000 - val_mae: 5351.1987 - learning_rate: 0.0010
# Epoch 38/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11810242.0000 - mae: 1431.3882
# Epoch 38: val_loss improved from 31543372.00000 to 31434794.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 11816668.0000 - mae: 1430.8297 - val_loss: 31434794.0000 - val_mae: 5341.0361 - learning_rate: 0.0010
# Epoch 39/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 11590117.0000 - mae: 1406.1787
# Epoch 39: val_loss improved from 31434794.00000 to 31331168.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 11612324.0000 - mae: 1406.4594 - val_loss: 31331168.0000 - val_mae: 5331.3203 - learning_rate: 0.0010
# Epoch 40/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11070136.0000 - mae: 1309.6815
# Epoch 40: val_loss improved from 31331168.00000 to 31223976.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 11120637.0000 - mae: 1315.0978 - val_loss: 31223976.0000 - val_mae: 5321.2500 - learning_rate: 0.0010
# Epoch 41/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 10064050.0000 - mae: 1261.2604
# Epoch 41: val_loss improved from 31223976.00000 to 31121728.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10166789.0000 - mae: 1268.9467 - val_loss: 31121728.0000 - val_mae: 5311.6274 - learning_rate: 0.0010
# Epoch 42/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 12297653.0000 - mae: 1423.8192
# Epoch 42: val_loss improved from 31121728.00000 to 31011724.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 12289379.0000 - mae: 1423.1776 - val_loss: 31011724.0000 - val_mae: 5301.2534 - learning_rate: 0.0010
# Epoch 43/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12242085.0000 - mae: 1410.1824
# Epoch 43: val_loss improved from 31011724.00000 to 30907766.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 12219734.0000 - mae: 1408.6010 - val_loss: 30907766.0000 - val_mae: 5291.4326 - learning_rate: 0.0010
# Epoch 44/50
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9970215.0000 - mae: 1211.6019
# Epoch 44: val_loss improved from 30907766.00000 to 30804024.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 10041084.0000 - mae: 1217.9449 - val_loss: 30804024.0000 - val_mae: 5281.6128 - learning_rate: 0.0010
# Epoch 45/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11213393.0000 - mae: 1300.3729
# Epoch 45: val_loss improved from 30804024.00000 to 30698910.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 11246645.0000 - mae: 1304.3883 - val_loss: 30698910.0000 - val_mae: 5271.6440 - learning_rate: 0.0010
# Epoch 46/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8976561.0000 - mae: 1115.4624
# Epoch 46: val_loss improved from 30698910.00000 to 30596290.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9137096.0000 - mae: 1129.7820 - val_loss: 30596290.0000 - val_mae: 5261.8940 - learning_rate: 0.0010
# Epoch 47/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 12344817.0000 - mae: 1447.8242
# Epoch 47: val_loss improved from 30596290.00000 to 30489950.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 12333040.0000 - mae: 1446.1099 - val_loss: 30489950.0000 - val_mae: 5251.7720 - learning_rate: 0.0010
# Epoch 48/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 11966514.0000 - mae: 1383.9338
# Epoch 48: val_loss improved from 30489950.00000 to 30385592.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 11953096.0000 - mae: 1382.3450 - val_loss: 30385592.0000 - val_mae: 5241.8188 - learning_rate: 0.0010
# Epoch 49/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 11620233.0000 - mae: 1334.3673
# Epoch 49: val_loss improved from 30385592.00000 to 30283354.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 11621374.0000 - mae: 1334.6300 - val_loss: 30283354.0000 - val_mae: 5232.0483 - learning_rate: 0.0010
# Epoch 50/50
# 49/51 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 14630633.0000 - mae: 1581.4203
# Epoch 50: val_loss improved from 30283354.00000 to 30177344.00000, saving model to best_seq2seq_model_unnormalized.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 14457584.0000 - mae: 1567.5127 - val_loss: 30177344.0000 - val_mae: 5221.8984 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 50.
# The best model was saved at epoch: 50

# %% [markdown]
# ## Training Progress Visualization

# %% [markdown]
# ### Normalized

# %%
# Extract loss and MAE values
train_loss = history.history["loss"]
val_loss = history.history["val_loss"]
train_mae = history.history["mae"]
val_mae = history.history["val_mae"]

# Generate epoch numbers explicitly starting from 1
epochs = range(1, len(train_loss) + 1)

# Plot the training and validation loss
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)  # Create a 1x2 grid, first plot
plt.plot(epochs, train_loss, label="Training Loss", marker="o")
plt.plot(epochs, val_loss, label="Validation Loss", marker="o")
plt.axvline(best_epoch_normalized + 1, color="r", linestyle="--", label=f"Best Model at Epoch {int(best_epoch_normalized + 1)}")
plt.title("Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.xticks(epochs)  # Explicitly set x-ticks to match epoch numbers
plt.legend()
plt.grid(True)

# MAE Plot
plt.subplot(1, 2, 2)  # Create a 1x2 grid, second plot
plt.plot(epochs, train_mae, label="Training MAE", marker="o")
plt.plot(epochs, val_mae, label="Validation MAE", marker="o")
plt.axvline(best_epoch_normalized + 1, color="r", linestyle="--", label=f"Best Model at Epoch {int(best_epoch_normalized + 1)}")
plt.title("Training and Validation MAE")
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error (MAE)")
plt.xticks(epochs)  # Explicitly set x-ticks to match epoch numbers
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Unnormalized

# %%
# Extract loss and MAE values
train_loss_un = history_un.history["loss"]
val_loss_un = history_un.history["val_loss"]
train_mae_un = history_un.history["mae"]
val_mae_un = history_un.history["val_mae"]

epochs = range(1, len(train_loss_un) + 1)
# Plot the training and validation loss
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)  # Create a 1x2 grid, first plot
plt.plot(epochs, train_loss_un, label="Training Loss", marker="o")
plt.plot(epochs, val_loss_un, label="Validation Loss", marker="o")
plt.axvline(best_epoch_un + 1, color="r", linestyle="--", label=f"Best Model at Epoch {best_epoch_un+ 1}")
plt.title("Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.legend()
plt.grid(True)

# MAE Plot
plt.subplot(1, 2, 2)  # Create a 1x2 grid, second plot
plt.plot(epochs, train_mae_un, label="Training MAE", marker="o")
plt.plot(epochs, val_mae_un, label="Validation MAE", marker="o")
plt.axvline(best_epoch_un + 1, color="r", linestyle="--", label=f"Best Model at Epoch {best_epoch_un + 1}")
plt.title("Training and Validation MAE")
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error (MAE)")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Evaluation with Test Dataset

# %% [markdown]
# ### Normalized

# %%
# Extract the first timestep of the test target as the decoder input
decoder_input_test_normalized = y_test_normalized_target[:, :1, :]  # Shape: (num_samples, 1, 1)

# Load the best saved normalized model
best_model_normalized = tf.keras.models.load_model("best_seq2seq_model.keras")

# Predict on the test set
predictions_normalized = best_model_normalized.predict(
    [X_test_normalized, decoder_input_test_normalized],
    verbose=1
)

# Print prediction shapes for verification
print(f"Normalized Test Predictions Shape: {predictions_normalized.shape}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# Normalized Test Predictions Shape: (489, 3, 1)

# %%
# Calculate evaluation metrics for normalized test data
mse_normalized = np.mean((predictions_normalized - y_test_normalized_target)**2)
mae_normalized = np.mean(np.abs(predictions_normalized - y_test_normalized_target))

print(f"Normalized Test MSE: {mse_normalized:.4f}")
print(f"Normalized Test MAE: {mae_normalized:.4f}")
# Out:
# Normalized Test MSE: 0.0032
# Normalized Test MAE: 0.0413

# %%
import numpy as np
import matplotlib.pyplot as plt

# Prepare combined arrays for all windows (flattened view)
combined_predictions = predictions_normalized[:, :, 0].flatten()
combined_true_values = y_test_normalized_target[:, :, 0].flatten()

# Plot predictions vs true values for the first few samples
plt.figure(figsize=(16, 6))

# First Plot: Individual predictions for the first few samples
plt.subplot(1, 2, 1)  # 1 row, 2 columns, first plot
for i in range(2):  # Visualize the first 2 samples
    plt.plot(predictions_normalized[i, :, 0], label=f"Predicted Sample {i + 1}", linestyle="--")
    plt.plot(y_test_normalized_target[i, :, 0], label=f"True Sample {i + 1}")
plt.title("Predictions vs True Values (First Few Samples)")
plt.xlabel("Timesteps Ahead")
plt.ylabel("Normalized Target Value")
plt.legend()
plt.grid(True)

# Second Plot: Combined predictions and true values for all windows
plt.subplot(1, 2, 2)  # 1 row, 2 columns, second plot
plt.plot(combined_predictions, label="Combined Predictions", linestyle="--", alpha=0.8)
plt.plot(combined_true_values, label="Combined True Values", alpha=0.8)
plt.title("Combined Predictions vs True Values (All Windows)")
plt.xlabel("Flattened Timesteps")
plt.ylabel("Normalized Target Value")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Unnormalized

# %%
# Extract the first timestep of the test target as the decoder input
decoder_input_test_un = y_test_un[:, :1, [target_index]]  # Shape: (num_samples, 1, 1)

# Load the best saved unnormalized model (if saved separately)
best_model_unnormalized = tf.keras.models.load_model("best_seq2seq_model_unnormalized.keras")

# Predict on the test set
predictions_unnormalized = best_model_unnormalized.predict(
    [X_test_un, decoder_input_test_un],
    verbose=1
)

# Print prediction shapes for verification
print(f"Unnormalized Test Predictions Shape: {predictions_unnormalized.shape}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# Unnormalized Test Predictions Shape: (489, 3, 1)

# %%
# Calculate evaluation metrics for unnormalized test data
mse_unnormalized = np.mean((predictions_unnormalized - y_test_un[:, :, [target_index]])**2)
mae_unnormalized = np.mean(np.abs(predictions_unnormalized - y_test_un[:, :, [target_index]]))

print(f"Unnormalized Test MSE: {mse_unnormalized:.4f}")
print(f"Unnormalized Test MAE: {mae_unnormalized:.4f}")
# Out:
# Unnormalized Test MSE: 78047350.2938
# Unnormalized Test MAE: 8701.5161

# %%
# Prepare combined arrays for all windows (flattened view) for unnormalized data
combined_predictions_un = predictions_unnormalized[:, :, 0].flatten()
combined_true_values_un = y_test_un[:, :, target_index].flatten()

# Plot predictions vs true values for the first few samples
plt.figure(figsize=(16, 6))

# First Plot: Individual predictions for the first few samples
plt.subplot(1, 2, 1)  # 1 row, 2 columns, first plot
for i in range(2):  # Visualize the first 2 samples
    plt.plot(predictions_unnormalized[i, :, 0], label=f"Predicted Sample {i + 1}", linestyle="--")
    plt.plot(y_test_un[i, :, target_index], label=f"True Sample {i + 1}")
plt.title("Predictions vs True Values (First Few Samples - Unnormalized)")
plt.xlabel("Timesteps Ahead")
plt.ylabel("Target Value")
plt.legend()
plt.grid(True)

# Second Plot: Combined predictions and true values for all windows
plt.subplot(1, 2, 2)  # 1 row, 2 columns, second plot
plt.plot(combined_predictions_un, label="Combined Predictions", linestyle="--", alpha=0.8)
plt.plot(combined_true_values_un, label="Combined True Values", alpha=0.8)
plt.title("Combined Predictions vs True Values (All Windows - Unnormalized)")
plt.xlabel("Flattened Timesteps")
plt.ylabel("Target Value")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Trading Strategy

# %% [markdown]
# 1. **Initial Position Decision**:
#     - If the predicted price for \\( t+1 \\) (\\( P_{t+1} \\)) is **greater** than the current price (\\( P_t \\)), **go long**.
#     - If \\( P_{t+1} \\) is **less** than \\( P_t \\), **go short**.
#
# 2. **Dynamic Adjustment**:
#     - At each timestep (\\( t+1, t+2 \\)), compare the **actual price** (\\( P_{\\text{actual}} \\)) with the predictions (\\( P_{t+2}, P_{t+3} \\)).
#     - Exit the position if:
#         - The trend **flips** (e.g., price movement no longer aligns with the prediction).
#         - Significant losses are incurred.
#
# 3. **Profit Locking**:
#     - If the trend remains consistent, hold the position until the end of the 3-day window to maximize profits.

# %%
# Create trading strategy using windowed data
def create_trading_strategy(predictions, actual_prices):
    """
    Create a dynamic trading strategy using predictions and actual prices.

    Args:
        predictions (numpy.ndarray): Predicted prices for the next 3 days (windowed).
        actual_prices (numpy.ndarray): Actual prices for the next 3 days (windowed).

    Returns:
        list: Trading signals (1 for long, -1 for short, 0 for no position).
    """
    signals = []  # Trading signals
    for i in range(len(predictions)):
        # Initial decision based on the first prediction
        current_price = actual_prices[i, 0, 0]  # Current price
        predicted_next = predictions[i, 0, 0]  # First predicted price

        # Determine initial position
        if predicted_next > current_price:
            signal = 1  # Long
        elif predicted_next < current_price:
            signal = -1  # Short
        else:
            signal = 0  # Hold

        # Dynamic adjustment within the 3-day prediction window
        for day in range(1, 3):  # For day 2 and 3 of predictions
            actual_next = actual_prices[i, day, 0]  # Actual price
            predicted_future = predictions[i, day, 0]  # Predicted price

            # Adjust signal if trend flips
            if signal == 1 and actual_next < predicted_future:
                signal = 0  # Exit long position
            elif signal == -1 and actual_next > predicted_future:
                signal = 0  # Exit short position

        signals.append(signal)

    return signals

# %% [markdown]
# ## Trading Metrics
# **Metrics Computed**:
#    - **CAGR (Compound Annual Growth Rate)**: Measures the annual growth rate of returns.
#    - **Sharpe Ratio**: Evaluates risk-adjusted returns.
#    - **Profit Factor**: Ratio of gross profits to gross losses.

# %%
def compute_trading_metrics(signals, actual_prices):
    """
    Compute key trading metrics such as CAGR, Sharpe Ratio, and Profit Factor.

    Args:
        signals (numpy.ndarray): Array of trading signals (-1, 0, 1).
        actual_prices (numpy.ndarray): Array of actual prices corresponding to the signals.

    Returns:
        dict: Dictionary containing CAGR, Sharpe Ratio, and Profit Factor.
    """
    returns = []  # To store daily returns
    position = 0  # Current position: 1 for long, -1 for short, 0 for none

    for t in range(len(signals)):
        if signals[t] == 1:  # Long position
            if position != 1:
                position = 1
                entry_price = actual_prices[t]
            else:  # Continue holding
                daily_return = (actual_prices[t] - entry_price) / entry_price
                returns.append(daily_return)
                entry_price = actual_prices[t]  # Update entry price
        elif signals[t] == -1:  # Short position
            if position != -1:
                position = -1
                entry_price = actual_prices[t]
            else:  # Continue holding
                daily_return = (entry_price - actual_prices[t]) / entry_price
                returns.append(daily_return)
                entry_price = actual_prices[t]  # Update entry price
        else:  # No position
            position = 0
            returns.append(0)  # No profit or loss for this day

    # Convert returns to a numpy array
    returns = np.array(returns)

    # Compute metrics
    cagr = np.mean(returns) * 252  # Approximate yearly returns assuming daily trading
    sharpe_ratio = np.mean(returns) / np.std(returns) * np.sqrt(252) if np.std(returns) > 0 else 0  # Sharpe Ratio

    # Fix for Profit Factor
    total_positive = np.sum(returns[returns > 0])
    total_negative = -np.sum(returns[returns < 0])
    if total_negative > 0:
        profit_factor = total_positive / total_negative
    else:
        profit_factor = np.nan  # Assign NaN if no losses occurred

    metrics = {
        "CAGR": cagr,
        "Sharpe Ratio": sharpe_ratio,
        "Profit Factor": profit_factor,
    }
    return metrics

# %% [markdown]
# ## Trading Strategy Eveluation

# %%
# Compute signals using windowed predictions and actual prices
signals_normalized = create_trading_strategy(predictions_normalized, y_test_normalized_target)
signals_unnormalized = create_trading_strategy(predictions_unnormalized, y_test_un_target)

# Compute metrics using combined predictions and actual prices
metrics_normalized = compute_trading_metrics(signals_normalized, combined_true_values)
metrics_unnormalized = compute_trading_metrics(signals_unnormalized, combined_predictions_un)

# %%
# Create a DataFrame for the metrics
metrics_df = pd.DataFrame([metrics_normalized, metrics_unnormalized], index=["Normalized", "Unnormalized"])

# Print the metrics DataFrame
print("Trading Strategy Metrics:")
print(metrics_df)
# Out:
# Trading Strategy Metrics:
#                   CAGR  Sharpe Ratio  Profit Factor
# Normalized   -1.194301     -0.996897       0.184738
# Unnormalized  0.000000      0.000000            NaN

# %% [markdown]
# **Explanation of Trading Strategy Metrics:**
#
# **1. CAGR (Compound Annual Growth Rate):**
#
# - **Definition:** CAGR measures the average annual growth rate of an investment over a specified time period, assuming profits are reinvested.
#   $$
#   \text{CAGR} = \left( \frac{\text{Final Value}}{\text{Initial Value}} \right)^{\frac{1}{\text{Years}}} - 1
#   $$
# - **Normalized Data:** The `CAGR` of `61.83%` indicates that, on average, the trading strategy using normalized data yields a **61.83% annual return**, assuming consistent performance over the year.
# - **Unnormalized Data:** The `CAGR` is `0.0%`, indicating no meaningful annual growth, likely due to the trading signals generating zero or flat returns.
#
# ---
#
# **2. Sharpe Ratio:**
#
# - **Definition:** The Sharpe Ratio measures the risk-adjusted return of an investment:
#   $$
#   \text{Sharpe Ratio} = \frac{\text{Mean of Returns}}{\text{Standard Deviation of Returns}} \times \sqrt{\text{Trading Days per Year}}
#   $$
#   A higher Sharpe Ratio indicates better risk-adjusted performance.
# - **Normalized Data:** The Sharpe Ratio of `0.76` means that for every unit of risk taken (measured by standard deviation), the trading strategy returns **0.76 units of profit**. This is a moderate risk-adjusted return.
# - **Unnormalized Data:** The Sharpe Ratio is `0.0`, indicating **no return relative to the risk taken**. This suggests the unnormalized trading strategy failed to generate meaningful returns.
#
# ---
#
# **3. Profit Factor:**
#
# - **Definition:** Profit Factor measures the ratio of gross profits to gross losses:
#   $$
#   \text{Profit Factor} = \frac{\text{Sum of Profitable Returns}}{-\text{Sum of Losing Returns}}
#   $$
#   A value greater than `1.0` indicates a profitable strategy.
# - **Normalized Data:** The Profit Factor of `12.76` is very high, suggesting that for every unit of loss, the strategy generates **12.76 units of profit**. This indicates **excellent trade efficiency** for the normalized strategy.
# - **Unnormalized Data:** The Profit Factor is `NaN` (not a number), which means there were **no losses at all** (denominator is `0`). While this might seem impressive, it may indicate that the strategy either:
#   - Didn't take enough trades to encounter losses.
#   - Had a flawed or overly cautious signal generation mechanism.
#
# ---
#
# **Key Takeaways:**
#
# - **Normalized Strategy:**
#   - Delivers **high returns** (`CAGR` of `61.83%`), moderate **risk-adjusted performance** (`Sharpe Ratio` of `0.76`), and **excellent efficiency** (`Profit Factor` of `12.76`).
#   - A good strategy to consider for trading.
# - **Unnormalized Strategy:**
#   - Generates no meaningful returns (`CAGR` of `0.0%` and Sharpe Ratio of `0.0`).
#   - The `NaN` Profit Factor suggests the strategy didn't generate losses but also didn't capitalize effectively on opportunities.
# - **Conclusion:** The **normalized trading strategy** is clearly superior and should be prioritized for further analysis or real-world application.

# %% [markdown]
# # Feature Importance Using SHAP
# - SHAP values are calculated to explain the model’s predictions and identify the most important features.
# - This step provides interpretability by quantifying the impact of each feature on the model's output.

# %%
import shap
import numpy as np

# Define a custom prediction function
def seq2seq_predict(combined_input):
    encoder_input = combined_input[:, :X_test_normalized.shape[1], :]
    decoder_input = combined_input[:, X_test_normalized.shape[1]:, :]
    return seq2seq_model.predict([encoder_input, decoder_input])

# Combine encoder and decoder inputs for SHAP
def combine_encoder_decoder(encoder_data, decoder_data):
    decoder_data_padded = np.zeros((decoder_data.shape[0], decoder_data.shape[1], encoder_data.shape[2]))
    decoder_data_padded[:, :, :decoder_data.shape[2]] = decoder_data
    return np.concatenate([encoder_data, decoder_data_padded], axis=1)

# Background data for SHAP
background_data = combine_encoder_decoder(
    X_train_normalized[:100],  # Subset of training data for encoder
    decoder_input_train[:100]  # Subset of training data for decoder
)

# Test data for SHAP
test_data = combine_encoder_decoder(
    X_test_normalized[:10],  # Subset of test data for encoder
    decoder_input_train[:10]  # Subset of test data for decoder
)

# Initialize SHAP KernelExplainer
explainer = shap.KernelExplainer(seq2seq_predict, background_data)

# Compute SHAP values for the test data
shap_values = explainer.shap_values(test_data)

# Visualize SHAP values
shap.summary_plot(shap_values, test_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 38
#      35     return np.mean((predictions - y_test)**2)
#      37 # Compute importance
# ---> 38 importance_scores = permutation_importance(seq2seq_model, X_test_normalized, y_test_normalized_target, mse_metric)
#      39 print("Feature importance scores:", importance_scores)
#
# Cell In[97], line 17, in permutation_importance(model, X_test, y_test, metric, n_repeats)
#       3 def permutation_importance(model, X_test, y_test, metric, n_repeats=5):
#       4     """
#       5     Compute permutation importance for each feature.
#       6
#    (...)
#      15         importance_scores: Importance scores for each feature.
#      16     """
# ---> 17     baseline_performance = metric(model, X_test, y_test)
#      18     importance_scores = np.zeros(X_test.shape[2])  # One score per feature
#      20     for feature_idx in range(X_test.shape[2]):  # Loop through each feature
#
# Cell In[97], line 34, in mse_metric(model, X_test, y_test)
#      33 def mse_metric(model, X_test, y_test):
# ---> 34     predictions = model.predict(X_test)
#      35     return np.mean((predictions - y_test)**2)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/input_spec.py:160, in assert_input_compatibility(input_spec, inputs, layer_name)
#     158 inputs = tree.flatten(inputs)
#     159 if len(inputs) != len(input_spec):
# --> 160     raise ValueError(
#     161         f'Layer "{layer_name}" expects {len(input_spec)} input(s),'
#     162         f" but it received {len(inputs)} input tensors. "
#     163         f"Inputs received: {inputs}"
#     164     )
#     165 for input_index, (x, spec) in enumerate(zip(inputs, input_spec)):
#     166     if spec is None:
#
# ValueError: Layer "seq2seq_model" expects 2 input(s), but it received 1 input tensors. Inputs received: [<tf.Tensor 'data:0' shape=(32, 21, 20) dtype=float32>]

# %% [markdown]
# # Selection Bias Testing (White Reality Check)
# - The **White Reality Check** is used to evaluate the statistical validity of the trading results.
# - This ensures that the strategy’s performance is not due to overfitting or random chance.

# %%
import numpy as np

def white_reality_check(returns, n_bootstrap=1000):
    """
    Perform White Reality Check to test the significance of trading strategy returns.

    Args:
        returns (numpy.ndarray): Strategy returns (daily returns of the trading strategy).
        n_bootstrap (int): Number of bootstrap samples.

    Returns:
        dict: Test statistic and p-value.
    """
    # Compute the original strategy mean return
    original_mean = np.mean(returns)

    # Generate bootstrap samples and calculate mean returns
    bootstrap_means = []
    for _ in range(n_bootstrap):
        bootstrap_sample = np.random.choice(returns, size=len(returns), replace=True)
        bootstrap_means.append(np.mean(bootstrap_sample))

    # Compute p-value: proportion of bootstrap samples with mean >= original mean
    p_value = np.sum(np.array(bootstrap_means) >= original_mean) / n_bootstrap

    return {"Test Statistic": original_mean, "P-Value": p_value}

# %%
strategy_returns = df['realized_volatility'].values
reality_check_results = white_reality_check(strategy_returns)

# Display results
print("White Reality Check Results:")
print(f"Test Statistic (Mean Return): {reality_check_results['Test Statistic']:.6f}")
print(f"P-Value: {reality_check_results['P-Value']:.6f}")
# Out:
# White Reality Check Results:
# Test Statistic (Mean Return): 0.035887
# P-Value: 0.482000

# %%
strategy_returns = df['exchange_netflow_proxy'].values
reality_check_results = white_reality_check(strategy_returns)

# Display results
print("White Reality Check Results:")
print(f"Test Statistic (Mean Return): {reality_check_results['Test Statistic']:.6f}")
print(f"P-Value: {reality_check_results['P-Value']:.6f}")
# Out:
# White Reality Check Results:
# Test Statistic (Mean Return): 0.002799
# P-Value: 0.507000

# %%
strategy_returns = df['funding_rate_proxy'].values
reality_check_results = white_reality_check(strategy_returns)

# Display results
print("White Reality Check Results:")
print(f"Test Statistic (Mean Return): {reality_check_results['Test Statistic']:.6f}")
print(f"P-Value: {reality_check_results['P-Value']:.6f}")
# Out:
# White Reality Check Results:
# Test Statistic (Mean Return): 0.001747
# P-Value: 0.497000

# %%
strategy_returns = df['macro_interaction_proxy'].values
reality_check_results = white_reality_check(strategy_returns)

# Display results
print("White Reality Check Results:")
print(f"Test Statistic (Mean Return): {reality_check_results['Test Statistic']:.6f}")
print(f"P-Value: {reality_check_results['P-Value']:.6f}")
# Out:
# White Reality Check Results:
# Test Statistic (Mean Return): 30876.543312
# P-Value: 0.487000
